# %%
# !pip install faiss-cpu --no-cache
# !pip install cohere
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 78.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0.post1
# Collecting cohere
#   Downloading cohere-5.13.6-py3-none-any.whl.metadata (3.5 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.28.1)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.10.4)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.27.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.21.0)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere) (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)
# Downloading cohere-5.13.6-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.2/250.2 kB 4.1 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading fastavro-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.3 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Installing collected packages: types-requests, parameterized, httpx-sse, fastavro, cohere
# Successfully installed cohere-5.13.6 fastavro-1.10.0 httpx-sse-0.4.0 parameterized-0.9.0 types-requests-2.32.0.20241016

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
import cohere
from google.colab import userdata
from sklearn.preprocessing import MinMaxScaler

# %%
#Datasets and preprocessing

lb_articles = pd.read_csv('lingbuzz_002_007537.csv')
#I saved embeddings as pkl because it takes too much time to generate everytime
lb_embeddings = pd.read_pickle('lb_embeddings.pkl')

#Converting 'Date' to datetime for later use in recency
lb_articles['Date'] = pd.to_datetime(lb_articles['Date'], format='%B %Y')

#Combining text data for later use in generation part as prompt
lb_articles['Combined_Text'] = lb_articles['Title'].fillna('') + ' ' + lb_articles['Abstract'].fillna('') + ' ' + lb_articles['Keywords'].fillna('')

#Concatenate embeddings and the actual dataset
lb_articles = pd.concat([lb_articles, lb_embeddings], axis=1)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
#Create and initialize a FAISS index for efficient nearest-neighbor search.
embedding_matrix = np.vstack(lb_articles['Embeddings'].values)
index = faiss.IndexFlatL2(embedding_matrix.shape[1])
index.add(embedding_matrix)

# %%
#Another method to find similarity, cosine similarity
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
#Popularity score with metadata
m_scaler = MinMaxScaler(feature_range=(0, 0.3))
lb_articles['Popularity_Score'] = m_scaler.fit_transform(lb_articles[['Downloads']])

# %%
#Recency score with metadata
recency_threshold = pd.Timestamp('2019-01-01')
lb_articles['Recency_Score'] = lb_articles['Date'].apply(lambda x: 0.1 if x >= recency_threshold else 0)

# %%
#Retrieveing articles with FAISS, it doesn't allow me to integrate metadat. That's why I will use cosine similarity for another option.
def retrieve_articles_faiss(query, k=5):
    query_embedding = model.encode([query])
    distances, indices = index.search(np.array(query_embedding), k)
    top_articles = lb_articles.iloc[indices[0]]
    return top_articles

# %%
#Retrieving articles with cosine similarity, and integrating metadata
def retrieve_articles_cosin(query, k=5, recent = False, popular = False):
    #Creating a copy of the df.
    articles_df = lb_articles.copy()
    #Generating the embedding for the query
    query_embedding = model.encode([query])

    #Calculating the cosine similarity score
    cosin_score = articles_df['Embeddings'].apply(lambda x: cosine_similarity(query_embedding, x))
    articles_df['Cosine_Score'] = cosin_score

    #Creating the 'Combined Score' column for combining metadata scores and cosine score
    articles_df['Combined_Score'] = articles_df['Cosine_Score']
    if recent:
      articles_df['Combined_Score'] += articles_df['Recency_Score']

    if popular:
      articles_df['Combined_Score'] += articles_df['Popularity_Score']

    #Sorting by combined score and returning top k
    sorted_articles = articles_df.sort_values(by='Combined_Score', ascending=False)
    top_articles = sorted_articles.head(k)
    return top_articles

# %%
#The language model I use for this project
co = cohere.Client(userdata.get('COHERE_API'))

# %%
def generate_response(query):

    relevant_docs = retrieve_articles_faiss(query)

    context = ' '.join(relevant_docs['Combined_Text'].tolist())

    response = co.generate(
        model='command-r-plus-04-2024',
        prompt=f"Based on the following research context, answer this query: '{query}'\n\nContext:\n{context}\n\nAnswer:",
        max_tokens=150,
        temperature=0.7,
        stop_sequences=["."]
    )

    return response.generations[0].text

# %%
def generate_response_metadata(query, recent=False, popular=False):

    relevant_docs = retrieve_articles_cosin(query, recent=recent, popular=popular)

    context = ' '.join(relevant_docs['Combined_Text'].tolist())

    response = co.generate(
        model='command-r-plus-04-2024',
        prompt=f"Based on the following research context, answer this query: '{query}'\n\nContext:\n{context}\n\nAnswer:",
        max_tokens=150,
        temperature=0.7,
        stop_sequences=["."]
    )

    return response.generations[0].text

# %%
retrieve_articles_faiss('what do people say about agree link?')
# Out:
#                    Id                                              Title  \
# 6332  lingbuzz/006504                            Current models of Agree
# 5716  lingbuzz/005888                           A short history of Agree
# 5670  lingbuzz/005842  Agree as derivational operation: Its definitio...
# 2757  lingbuzz/002929       Agree and agreement: evidence from Germanic.
# 6172  lingbuzz/006344                 Negative concord as downward Agree
#
#                         Authors  \
# 6332              Amy Rose Deal
# 5716       Roberta D'Alessandro
# 5670              Daniel Milway
# 2757  Halldor Armann Sigurdsson
# 6172              Amy Rose Deal
#
#                                                Keywords  \
# 6332  agreement, uninterpretable, interaction, satis...
# 5716  agree, agreement, phi features, minimalist pro...
# 5670  theory, formalization, minimalism, agree, deri...
# 2757  agree, agreement, merge, germanic languages, m...
# 6172  agree, upward, downward, direction, directiona...
#
#                                            Published_in       Date  Downloads  \
# 6332  To appear in James Crippen, Rose- Marie Dechai... 2023-03-01     1332.0
# 5716  2nd draft. To appear in the Cambridge Handbook... 2022-06-01     1169.0
# 5670                                 Biolinguistics. 17 2022-12-01     1592.0
# 2757  Focus on Germanic Typology, Studia Typologica ... 2004-04-01      547.0
# 6172                             Proceedings of NELS 52 2022-06-01     1245.0
#
#                                                Abstract  \
# 6332  This paper is an opinionated survey of issues ...
# 5716  Agreement has come to occupy a central role in...
# 5670  Using the framework laid out by Collins and St...
# 2757  This (final prepublication version of a) 2004 ...
# 6172  Negative concord (NC) plays a prominent role i...
#
#                                           Combined_Text  \
# 6332  Current models of Agree This paper is an opini...
# 5716  A short history of Agree Agreement has come to...
# 5670  Agree as derivational operation: Its definitio...
# 2757  Agree and agreement: evidence from Germanic. T...
# 6172  Negative concord as downward Agree Negative co...
#
#                                              Embeddings  Popularity_Score  \
# 6332  [-0.031272154, 0.004604514, 0.038683824, 0.013...          0.007828
# 5716  [-0.06614656, 0.015629102, 0.06707531, -0.0446...          0.006870
# 5670  [-0.032940015, 0.045070525, 0.014109657, -0.01...          0.009356
# 2757  [-0.05200358, 0.029110368, 0.068295985, 0.0005...          0.003215
# 6172  [-0.07408618, -0.015185226, 0.059860818, -0.03...          0.007317
#
#       Recency_Score
# 6332            0.1
# 5716            0.1
# 5670            0.1
# 2757            0.0
# 6172            0.1

# %%
retrieve_articles_cosin('what do people say about agree link?', recent=True, popular=True)
# Out:
#                    Id                                              Title  \
# 6332  lingbuzz/006504                            Current models of Agree
# 5716  lingbuzz/005888                           A short history of Agree
# 5670  lingbuzz/005842  Agree as derivational operation: Its definitio...
# 6172  lingbuzz/006344                 Negative concord as downward Agree
# 3496  lingbuzz/003668  Against some approaches to long-distance agree...
#
#                    Authors                                           Keywords  \
# 6332         Amy Rose Deal  agreement, uninterpretable, interaction, satis...
# 5716  Roberta D'Alessandro  agree, agreement, phi features, minimalist pro...
# 5670         Daniel Milway  theory, formalization, minimalism, agree, deri...
# 6172         Amy Rose Deal  agree, upward, downward, direction, directiona...
# 3496     Carson T. Schütze  agree, minimalism, long-distance agreement, sp...
#
#                                            Published_in       Date  Downloads  \
# 6332  To appear in James Crippen, Rose- Marie Dechai... 2023-03-01     1332.0
# 5716  2nd draft. To appear in the Cambridge Handbook... 2022-06-01     1169.0
# 5670                                 Biolinguistics. 17 2022-12-01     1592.0
# 6172                             Proceedings of NELS 52 2022-06-01     1245.0
# 3496  "Contrast and Representations in Syntax", ed. ... 2019-10-01      648.0
#
#                                                Abstract  \
# 6332  This paper is an opinionated survey of issues ...
# 5716  Agreement has come to occupy a central role in...
# 5670  Using the framework laid out by Collins and St...
# 6172  Negative concord (NC) plays a prominent role i...
# 3496  With the introduction of AGREE into Minimalism...
#
#                                           Combined_Text  \
# 6332  Current models of Agree This paper is an opini...
# 5716  A short history of Agree Agreement has come to...
# 5670  Agree as derivational operation: Its definitio...
# 6172  Negative concord as downward Agree Negative co...
# 3496  Against some approaches to long-distance agree...
#
#                                              Embeddings  Popularity_Score  \
# 6332  [-0.031272154, 0.004604514, 0.038683824, 0.013...          0.007828
# 5716  [-0.06614656, 0.015629102, 0.06707531, -0.0446...          0.006870
# 5670  [-0.032940015, 0.045070525, 0.014109657, -0.01...          0.009356
# 6172  [-0.07408618, -0.015185226, 0.059860818, -0.03...          0.007317
# 3496  [-0.024534931, 0.042681787, 0.03475321, -0.028...          0.003808
#
#       Recency_Score  Cosine_Score Combined_Score
# 6332            0.1  [0.44132763]   [0.54915607]
# 5716            0.1  [0.38662437]   [0.49349478]
# 5670            0.1   [0.3718493]   [0.48120573]
# 6172            0.1  [0.36013806]   [0.46745512]
# 3496            0.1  [0.33205017]   [0.43585858]

# %%
generate_response('what do people say about agree link?')
# Out:
# 'The research context includes a range of perspectives and opinions on Agree, a fundamental concept in syntactic theory.'

# %%
generate_response_metadata('what do people say about agree link?')
# Out:
# 'The research context includes a range of perspectives and opinions on the concept of "Agree" in syntactic theory.'
